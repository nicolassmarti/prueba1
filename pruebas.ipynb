# %%
print("Hola desde Jupyter 🚀")
# Out:
# Hola desde Jupyter 🚀

# %%
x = 10
y = 5
print("Suma:", x + y)
print("Multiplicación:", x * y)
# Out:
# Suma: 15
# Multiplicación: 50

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Nicolas Uniandes\AppData\Local\Programs\Python\Python314\python.exe

# %%
import math

numeros = [1, 2, 3, 4, 5]
cuadrados = [n**2 for n in numeros]

print("Números:", numeros)
print("Cuadrados:", cuadrados)
print("Raíz de 25:", math.sqrt(25))
# Out:
# Números: [1, 2, 3, 4, 5]
# Cuadrados: [1, 4, 9, 16, 25]
# Raíz de 25: 5.0
